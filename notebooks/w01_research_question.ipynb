# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# I’m choosing a freestyle lane because cannibalization feels like a real SEO problem
# that can waste a lot of effort if it is not caught early.
#
# My idea is to build a cannibalization early-warning system by constructing a graph
# from shared signals like queries, URLs, and content relationships, then using a
# LightGBM classifier on leading-indicator features to flag risky pages or clusters
# before performance drops.
#
# I like this direction because it is practical, connected to real editorial decisions,
# and useful for prioritization. I may also add query-text similarity later if it helps,
# but I want to start with structured signals first.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# The decision I’m trying to support is which pages may be competing with each other
# and should be reviewed first.
#
# The action would be taken by an SEO or content team, who could decide whether to
# consolidate pages, adjust targeting, rewrite content, or leave things as they are.
#
# A wrong recommendation could lead to unnecessary edits on pages that are already fine,
# while missing real cannibalization could keep splitting rankings, clicks, and search
# visibility across multiple pages.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

print(f"Rows: {len(df):,}")
print(f"Unique clients: {df['client_id'].nunique():,}")
print(f"Pages trending down: {(df['trend_direction'] == 'down').mean():.1%}")
print(f"Pages with zero clicks in the last 30d: {(df['clicks_last_30d'] == 0).mean():.1%}")
print(f"Pages not updated in over 30 days: {(df['days_since_last_update'] > 30).mean():.1%}")

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# I can say which pages or page pairs look risky based on the signals in the data, and
# I can rank them for review before performance gets worse.
#
# This should help with decision-support for SEO and content teams, especially when
# they need to decide whether to consolidate, retarget, or revise content.
#
# I cannot claim that the model proves cannibalization caused a drop, or that it predicts
# search engine behavior with certainty. I also should not treat the output as final truth.
# It is a warning system based on observed patterns, not causal proof.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
